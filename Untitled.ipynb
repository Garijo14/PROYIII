# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("base_trabajo_2.csv")

# %%
df.drop(df.columns[0],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['time', 'gen..kW.', 'House.overall..kW.', 'Dishwasher..kW.',
#        'Furnace.1..kW.', 'Furnace.2..kW.', 'Home.office..kW.', 'Fridge..kW.',
#        'Wine.cellar..kW.', 'Garage.door..kW.', 'Kitchen.12..kW.',
#        'Kitchen.14..kW.', 'Kitchen.38..kW.', 'Barn..kW.', 'Well..kW.',
#        'Microwave..kW.', 'Living.room..kW.', 'temperature', 'icon', 'humidity',
#        'visibility', 'summary', 'apparentTemperature', 'pressure', 'windSpeed',
#        'cloudCover', 'windBearing', 'precipIntensity', 'dewPoint',
#        'precipProbability'],
#       dtype='object')

# %%
df
# Out:
#                        time  gen..kW.  House.overall..kW.  Dishwasher..kW.  \
# 0       2016-01-01 00:58:00  0.003417            0.714200         0.000033
# 1       2016-01-01 00:59:00  0.003417            0.497067         0.000017
# 2       2016-01-01 01:00:00  0.003450            0.465133         0.000017
# 3       2016-01-01 01:01:00  0.003417            0.512933         0.000017
# 4       2016-01-01 01:02:00  0.003417            0.651283         0.000017
# ...                     ...       ...                 ...              ...
# 503847  2016-12-15 22:25:00  0.003183            1.601233         0.000050
# 503848  2016-12-15 22:26:00  0.003233            1.599333         0.000050
# 503849  2016-12-15 22:27:00  0.003217            1.924267         0.000033
# 503850  2016-12-15 22:28:00  0.003217            1.978200         0.000050
# 503851  2016-12-15 22:29:00  0.003233            1.990950         0.000050
#
#         Furnace.1..kW.  Furnace.2..kW.  Home.office..kW.  Fridge..kW.  \
# 0             0.021083        0.309983          0.043067     0.005167
# 1             0.096983        0.062867          0.043283     0.005000
# 2             0.064500        0.062633          0.043250     0.005017
# 3             0.111333        0.063883          0.043300     0.004967
# 4             0.114583        0.063200          0.043283     0.114167
# ...                ...             ...               ...          ...
# 503847        0.085267        0.642417          0.041783     0.005267
# 503848        0.104017        0.625033          0.041750     0.005233
# 503849        0.422383        0.637733          0.042033     0.004983
# 503850        0.495667        0.620367          0.042100     0.005333
# 503851        0.494700        0.634133          0.042100     0.004917
#
#         Wine.cellar..kW.  Garage.door..kW.  ...  visibility        summary  \
# 0               0.123317          0.013183  ...       10.00  Mostly Cloudy
# 1               0.123283          0.012883  ...       10.00  Mostly Cloudy
# 2               0.123350          0.012950  ...       10.00  Mostly Cloudy
# 3               0.123867          0.012883  ...       10.00  Mostly Cloudy
# 4               0.124267          0.012917  ...       10.00  Mostly Cloudy
# ...                  ...               ...  ...         ...            ...
# 503847          0.008667          0.013483  ...        8.74     Light Rain
# 503848          0.008433          0.013433  ...        8.74     Light Rain
# 503849          0.008467          0.012933  ...        8.74     Light Rain
# 503850          0.008233          0.012817  ...        8.74     Light Rain
# 503851          0.008133          0.012833  ...        8.74     Light Rain
#
#         apparentTemperature  pressure  windSpeed  cloudCover  windBearing  \
# 0                     -1.44   1016.25       8.29        0.75          285
# 1                     -1.44   1016.25       8.29        0.75          285
# 2                     -1.44   1016.25       8.29        0.75          285
# 3                     -1.44   1016.25       8.29        0.75          285
# 4                     -1.44   1016.25       8.29        0.75          285
# ...                     ...       ...        ...         ...          ...
# 123096                 1.36   1011.05      19.48        0.18          306
# 123081                 1.36   1011.05      19.48        0.18          306
# 195004                 6.38   1021.18       2.25        0.03          322
# 196502                 7.17   1021.40       1.57        0.03          269
# 123097                 1.36   1011.05      19.48        0.18          306
# 62550                -20.28   1034.56       2.32        0.00          229
# 196495                 7.17   1021.40       1.57        0.03          269
# 196496                 7.17   1021.40       1.57        0.03          269
# 172004                10.96   1010.70       4.95        1.00           26
# 195014                 6.38   1021.18       2.25        0.03          322
# 196509                 6.89   1021.56       1.71        0.07          268
# 172040                11.15   1010.12       5.46        1.00           23
# 123098                 1.36   1011.05      19.48        0.18          306
# 56884                 -5.58   1004.47       6.28        0.21          287
# 231000                13.38   1013.59       6.63        0.01          268
# 123100                 1.36   1011.05      19.48        0.18          306
# 171982                10.96   1010.70       4.95        1.00           26
# 88545                 -3.40   1018.92      10.01        0.09           41
# 88544                 -3.40   1018.92      10.01        0.09           41
# 194994                 6.80   1021.13       1.57        0.08            4
# 123099                 1.36   1011.05      19.48        0.18          306
# 196500                 7.17   1021.40       1.57        0.03          269
# 195015                 6.38   1021.18       2.25        0.03          322
# 111523                -3.65   1011.43       3.73        0.78            6
# 194995                 6.80   1021.13       1.57        0.08            4
# 56828                 -4.78   1004.33       5.76        0.28          272
# 172029                11.15   1010.12       5.46        1.00           23
# 56882                 -5.58   1004.47       6.28        0.21          287
# 101440                 8.83   1020.03       3.55        0.01           39
# 157537                14.03   1008.54       5.24        0.31          336
#
#         precipIntensity dewPoint  precipProbability
# 123096           0.0000    -3.49               0.00
# 123081           0.0000    -3.49               0.00
# 195004           0.0000     5.34               0.00
# 196502           0.0000     5.26               0.00
# 123097           0.0000    -3.49               0.00
# 62550            0.0000   -26.28               0.00
# 196495           0.0000     5.26               0.00
# 196496           0.0000     5.26               0.00
# 172004           0.0000     7.94               0.00
# 195014           0.0000     5.34               0.00
# 196509           0.0000     5.33               0.00
# 172040           0.0000     7.74               0.00
# 123098           0.0000    -3.49               0.00
# 56884            0.0000    -6.68               0.00
# 231000           0.0000     9.77               0.00
# 123100           0.0000    -3.49               0.00
# 171982           0.0000     7.94               0.00
# 88545            0.0000    -7.78               0.00
# 88544            0.0000    -7.78               0.00
# 194994           0.0000     5.79               0.00
# 123099           0.0000    -3.49               0.00
# 196500           0.0000     5.26               0.00
# 195015           0.0000     5.34               0.00
# 111523           0.0073    -3.33               0.36
# 194995           0.0000     5.79               0.00
# 56828            0.0000    -6.05               0.00
# 172029           0.0000     7.74               0.00
# 56882            0.0000    -6.68               0.00
# 101440           0.0000    -4.20               0.00
# 157537           0.0000    12.49               0.00
#
# [30 rows x 30 columns]

# %%
n = 21
label = df.columns[n]
plt.hist(df.iloc[:,n])
plt.title(label)
#plt.xticks(rotation=45, ha='right')
plt.show()

# %%
n = 21  # Suponiendo que quieres trazar la columna 18 del DataFrame
label = df.columns[n]

fig, (ax0,ax1) = plt.subplots(1,2, figsize=(10,4))

# Contar la frecuencia de cada categoría en la columna n
counts = df.iloc[:, n].value_counts()

# Crear un gráfico de barras
ax0.bar(counts.index, counts.values)

# Añadir título al gráfico
#ax0.set_title(label)

# Rotar las etiquetas del eje x en diagonal
ax0.set_xticklabels(counts.index, rotation=45, ha='right')
# Crear un gráfico de barras
ax1.pie(counts.values, labels=counts.index)

# Añadir título al gráfico
#ax1.set_title(label)

#plt.title(label)

plt.savefig("summary.png", bbox_inches='tight')

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\javil\AppData\Local\Temp\ipykernel_35208\4277895432.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax0.set_xticklabels(counts.index, rotation=45, ha='right')

# %%
# Crear un gráfico de barras

plt.bar(counts.index, counts.values)

# Añadir título al gráfico
plt.title(label)

# Rotar las etiquetas del eje x en diagonal
plt.xticks(rotation=45, ha='right')


plt.savefig("summary.png", bbox_inches='tight')

# Mostrar el gráfico
plt.show()

# %%
# Crear un gráfico de barras
plt.pie(counts.values, labels=counts.index)

# Añadir título al gráfico
plt.title(label)

# Rotar las etiquetas del eje x en diagonal
plt.xticks(rotation=45, ha='right')
plt.savefig("summary3.png", bbox_inches='tight')

# Mostrar el gráfico
plt.show()

# %%
counts
# Out:
# summary
# Clear                       376672
# Partly Cloudy                62268
# Light Rain                   27368
# Drizzle                      10370
# Overcast                      6041
# Rain                          5169
# Mostly Cloudy                 4548
# Light Snow                    4323
# Flurries                      1789
# Breezy                        1561
# Snow                          1152
# Breezy and Partly Cloudy      1041
# Foggy                          974
# Rain and Breezy                174
# Heavy Snow                     171
# Flurries and Breezy            115
# Breezy and Mostly Cloudy        58
# Dry                             58
# Name: count, dtype: int64

# %%
# Renaming Summary variable
# Clear, Cloudy, Rain, Snow, Wind
df["summary"] = df["summary"].replace("Partly Cloudy", "Cloudy")
df["summary"] = df["summary"].replace("Light Rain", "Rain")
df["summary"] = df["summary"].replace("Drizzle", "Rain")
df["summary"] = df["summary"].replace("Overcast", "Cloudy")
df["summary"] = df["summary"].replace("Mostly Cloudy", "Cloudy")
df["summary"] = df["summary"].replace("Light Snow", "Snow")
df["summary"] = df["summary"].replace("Flurries", "Other")
df["summary"] = df["summary"].replace("Breezy", "Other")
df["summary"] = df["summary"].replace("Breezy and Partly Cloudy", "Other")
df["summary"] = df["summary"].replace("Foggy", "Other")
df["summary"] = df["summary"].replace("Rain and Breezy", "Rain")
df["summary"] = df["summary"].replace("Heavy Snow", "Snow")
df["summary"] = df["summary"].replace("Flurries and Breezy", "Snow")
df["summary"] = df["summary"].replace("Breezy and Mostly Cloudy", "Cloudy")
df["summary"] = df["summary"].replace("Dry", "Clear")

# %%
n = 21  # Suponiendo que quieres trazar la columna 18 del DataFrame
label = df.columns[n]

# Contar la frecuencia de cada categoría en la columna n
counts = df.iloc[:, n].value_counts()

# Crear un gráfico de barras
plt.bar(counts.index, counts.values)

# Añadir título al gráfico
plt.title(label)

# Rotar las etiquetas del eje x en diagonal
plt.xticks(rotation=45, ha='right')

plt.savefig("summary2.png", bbox_inches='tight')

# Mostrar el gráfico
plt.show()

# %%
n = 29
label = df.columns[n]
plt.hist(df.iloc[:,n])
plt.title(label)
#plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df.loc[df["cloudCover"] > 0.79].cloudCover.hist()
plt.show()

# %%
df.
